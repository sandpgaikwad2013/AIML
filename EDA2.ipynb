# %%
# case study - jupyter notebook

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option("display.max_columns",300)
pd.set_option("display.max_rows",500)

# %%
df = pd.read_csv("telecom_churn_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Columns: 226 entries, mobile_number to sep_vbc_3g
# dtypes: float64(179), int64(35), object(12)
# memory usage: 172.4+ MB

# %%
df.head()
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109             0.0             0.0             0.0
# 1     7001865778        109             0.0             0.0             0.0
# 2     7001625959        109             0.0             0.0             0.0
# 3     7001204172        109             0.0             0.0             0.0
# 4     7000142493        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# 1            6/30/2014            7/31/2014            8/31/2014
# 2            6/30/2014            7/31/2014            8/31/2014
# 3            6/30/2014            7/31/2014            8/31/2014
# 4            6/30/2014            7/31/2014            8/31/2014
#
#   last_date_of_month_9   arpu_6  ...  sachet_3g_9  fb_user_6  fb_user_7  \
# ...

# %%
100*df.isna().sum()/len(df)
# Out:
# mobile_number                0.000000
# circle_id                    0.000000
# loc_og_t2o_mou               1.018010
# std_og_t2o_mou               1.018010
# loc_ic_t2o_mou               1.018010
# last_date_of_month_6         0.000000
# last_date_of_month_7         0.601006
# last_date_of_month_8         1.100011
# last_date_of_month_9         1.659017
# arpu_6                       0.000000
# arpu_7                       0.000000
# arpu_8                       0.000000
# arpu_9                       0.000000
# onnet_mou_6                  3.937039
# onnet_mou_7                  3.859039
# onnet_mou_8                  5.378054
# onnet_mou_9                  7.745077
# offnet_mou_6                 3.937039
# offnet_mou_7                 3.859039
# offnet_mou_8                 5.378054
# offnet_mou_9                 7.745077
# roam_ic_mou_6                3.937039
# roam_ic_mou_7                3.859039
# roam_ic_mou_8                5.378054
# roam_ic_mou_9                7.745077
# ...

# %%
result =100*df.isna().sum()/len(df)
type(result)
result.sort_values(ascending=False)
# Out:
# arpu_3g_6                   74.846748
# night_pck_user_6            74.846748
# total_rech_data_6           74.846748
# arpu_2g_6                   74.846748
# max_rech_data_6             74.846748
# fb_user_6                   74.846748
# av_rech_amt_data_6          74.846748
# date_of_last_rech_data_6    74.846748
# count_rech_2g_6             74.846748
# count_rech_3g_6             74.846748
# date_of_last_rech_data_7    74.428744
# total_rech_data_7           74.428744
# fb_user_7                   74.428744
# max_rech_data_7             74.428744
# night_pck_user_7            74.428744
# count_rech_2g_7             74.428744
# av_rech_amt_data_7          74.428744
# arpu_2g_7                   74.428744
# count_rech_3g_7             74.428744
# arpu_3g_7                   74.428744
# total_rech_data_9           74.077741
# count_rech_3g_9             74.077741
# fb_user_9                   74.077741
# max_rech_data_9             74.077741
# arpu_3g_9                   74.077741
# ...

# %%
# remove the coluns whoes null values are more than 30%

# %%
clean_df =df.loc[:,result<30]
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Columns: 186 entries, mobile_number to sep_vbc_3g
# dtypes: float64(143), int64(35), object(8)
# memory usage: 141.9+ MB

# %%
clean_df.isna().sum()*100/len(df)
# Out:
# mobile_number           0.000000
# circle_id               0.000000
# loc_og_t2o_mou          1.018010
# std_og_t2o_mou          1.018010
# loc_ic_t2o_mou          1.018010
# last_date_of_month_6    0.000000
# last_date_of_month_7    0.601006
# last_date_of_month_8    1.100011
# last_date_of_month_9    1.659017
# arpu_6                  0.000000
# arpu_7                  0.000000
# arpu_8                  0.000000
# arpu_9                  0.000000
# onnet_mou_6             3.937039
# onnet_mou_7             3.859039
# onnet_mou_8             5.378054
# onnet_mou_9             7.745077
# offnet_mou_6            3.937039
# offnet_mou_7            3.859039
# offnet_mou_8            5.378054
# offnet_mou_9            7.745077
# roam_ic_mou_6           3.937039
# roam_ic_mou_7           3.859039
# roam_ic_mou_8           5.378054
# roam_ic_mou_9           7.745077
# roam_og_mou_6           3.937039
# roam_og_mou_7           3.859039
# roam_og_mou_8           5.378054
# ...

# %%
df_clean =100*clean_df.isna().sum()/len(df)
type(result)
df_clean.sort_values(ascending=True)
# Out:
# mobile_number           0.000000
# last_day_rch_amt_7      0.000000
# last_day_rch_amt_6      0.000000
# date_of_last_rech_8     0.000000
# date_of_last_rech_7     0.000000
# date_of_last_rech_6     0.000000
# max_rech_amt_9          0.000000
# max_rech_amt_8          0.000000
# max_rech_amt_7          0.000000
# max_rech_amt_6          0.000000
# total_rech_amt_9        0.000000
# total_rech_amt_8        0.000000
# last_day_rch_amt_8      0.000000
# total_rech_amt_7        0.000000
# total_rech_num_9        0.000000
# total_rech_num_8        0.000000
# total_rech_num_7        0.000000
# total_rech_num_6        0.000000
# total_ic_mou_9          0.000000
# total_ic_mou_8          0.000000
# total_ic_mou_7          0.000000
# total_ic_mou_6          0.000000
# jun_vbc_3g              0.000000
# total_og_mou_9          0.000000
# total_og_mou_8          0.000000
# total_rech_amt_6        0.000000
# last_day_rch_amt_9      0.000000
# vol_2g_mb_6             0.000000
# ...

# %%
clean_df["std_og_t2o_mou"].fillna(clean_df["std_og_t2o_mou"].median(),inplace=True)
clean_df["loc_ic_t2o_mou"].fillna(clean_df["loc_ic_t2o_mou"].median(),inplace=True)
clean_df["loc_og_t2o_mou"].fillna(clean_df["loc_og_t2o_mou"].column(),inplace=True)
# date 
clean_df["last_date_of_month_8"].fillna(clean_df["last_date_of_month_8"].mode()[0],inplace=True)
clean_df["date_of_last_rech_6"].fillna(clean_df["date_of_last_rech_6"].mode()[0],inplace=True)
clean_df["last_date_of_month_9"].fillna(clean_df["last_date_of_month_9"].mode()[0],inplace=True)
clean_df["date_of_last_rech_7"].fillna(clean_df["date_of_last_rech_7"].mode()[0],inplace=True)
clean_df["date_of_last_rech_8"].fillna(clean_df["date_of_last_rech_8"].mode()[0],inplace=True)

# %%
# selecting numerical data types 
columns=clean_df.select_dtypes(include=["float64"]).columns
# Out:
# Index(['loc_og_t2o_mou', 'std_og_t2o_mou', 'loc_ic_t2o_mou', 'arpu_6',
#        'arpu_7', 'arpu_8', 'arpu_9', 'onnet_mou_6', 'onnet_mou_7',
#        'onnet_mou_8',
#        ...
#        'vol_2g_mb_8', 'vol_2g_mb_9', 'vol_3g_mb_6', 'vol_3g_mb_7',
#        'vol_3g_mb_8', 'vol_3g_mb_9', 'aug_vbc_3g', 'jul_vbc_3g', 'jun_vbc_3g',
#        'sep_vbc_3g'],
#       dtype='object', length=143)

# %%
clean_df=clean_df[columns].apply(lambda column:column.median())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [62], line 1
# ----> 1 clean_df=clean_df[columns].apply(lambda column:column.median())
#
# NameError: name 'columns' is not defined
