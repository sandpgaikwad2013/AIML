# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
ls
# Out:
# 1.py                     AIML_11th_Aug2024.ipynb  Untitled.ipynb
# 2024_8_18_Pandas.ipynb   NumPy_17_August.ipynb    day.csv
# AIML.iml                 Numpy_17thAugust.ipynb   loan.csv
# AIML_10th_Aug2024.ipynb  README.md                output.csv

# %%
loan_data=pd.read_csv("loan.csv")
# Out:
# /var/folders/l6/jtcss7dd195fkk1kwkwwblwc0000gn/T/ipykernel_16593/1758838580.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan_data=pd.read_csv("loan.csv")

# %%
import seaborn as sns

# %%
loan_data
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ...  \
# 0       36 months   10.65%       162.87     B        B2  ...
# 1       60 months   15.27%        59.83     C        C4  ...
# 2       36 months   15.96%        84.33     C        C5  ...
# 3       36 months   13.49%       339.31     C        C1  ...
# 4       60 months   12.69%        67.79     B        B5  ...
# ...           ...      ...          ...   ...       ...  ...
# 39712   36 months    8.07%        78.42     A        A4  ...
# 39713   36 months   10.28%       275.38     C        C1  ...
# 39714   36 months    8.07%       156.84     A        A4  ...
# 39715   36 months    7.43%       155.38     A        A2  ...
# 39716   36 months   13.75%       255.43     E        E2  ...
#
#       num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                    NaN                NaN            NaN               NaN
# 1                    NaN                NaN            NaN               NaN
# 2                    NaN                NaN            NaN               NaN
# 3                    NaN                NaN            NaN               NaN
# 4                    NaN                NaN            NaN               NaN
# ...                  ...                ...            ...               ...
# 39712                NaN                NaN            NaN               NaN
# 39713                NaN                NaN            NaN               NaN
# 39714                NaN                NaN            NaN               NaN
# 39715                NaN                NaN            NaN               NaN
# 39716                NaN                NaN            NaN               NaN
#
#       pub_rec_bankruptcies tax_liens tot_hi_cred_lim total_bal_ex_mort  \
# 0                      0.0       0.0             NaN               NaN
# 1                      0.0       0.0             NaN               NaN
# 2                      0.0       0.0             NaN               NaN
# 3                      0.0       0.0             NaN               NaN
# 4                      0.0       0.0             NaN               NaN
# ...                    ...       ...             ...               ...
# 39712                  NaN       NaN             NaN               NaN
# 39713                  NaN       NaN             NaN               NaN
# 39714                  NaN       NaN             NaN               NaN
# 39715                  NaN       NaN             NaN               NaN
# 39716                  NaN       NaN             NaN               NaN
#
#       total_bc_limit total_il_high_credit_limit
# 0                NaN                        NaN
# 1                NaN                        NaN
# 2                NaN                        NaN
# 3                NaN                        NaN
# 4                NaN                        NaN
# ...              ...                        ...
# 39712            NaN                        NaN
# 39713            NaN                        NaN
# 39714            NaN                        NaN
# 39715            NaN                        NaN
# 39716            NaN                        NaN
#
# [39717 rows x 111 columns]

# %%
#plt.subplot(3, 3, 1) 
sns.histplot(loan_data['loan_amnt'].dropna(), kde=True) 
plt.title('Histogram of Loan Amount by Amit')
# Out:
# Text(0.5, 1.0, 'Histogram of Loan Amount by Amit')

# %%
plt.subplot(2, 2, 1)
sns.histplot(loan_data['loan_amnt'].dropna(), kde=True)
plt.title('Histogram of Loan Amount by Amit')

plt.subplot(2, 2, 3)
sns.boxplot(x=loan_data['int_rate'].str.rstrip('%').astype(float))
plt.title('Box Plot of Interest Rate') 

plt.subplot(2, 2, 2)
sns.countplot(x=loan_data['grade']) 
plt.title('Bar Plot of Loan Grades')

plt.subplot(2, 2, 4) 
loan_term_counts = loan_data['term'].value_counts()
plt.pie(loan_term_counts, labels=loan_term_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Loan Term') 
plt.tight_layout() 
plt.show()
