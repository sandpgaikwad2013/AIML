# %%
import pandas as pd

# %%
ls
# Out:
# 1.py                     EDA_Data_Sourcing.xlsx   census+data.xlsx
# 2024_8_18_Pandas.ipynb   NumPy_17_August.ipynb    census_data.ipynb
# AIML.iml                 Numpy_17thAugust.ipynb   day.csv
# AIML_10th_Aug2024.ipynb  README.md                loan.csv
# AIML_11th_Aug2024.ipynb  Untitled.ipynb           output.csv

# %%
pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 1.1 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 24.2
# [notice] To update, run: pip3.10 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df =pd.read_excel("census+data.xlsx")

# %%
df.tail(5)
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2                         Unnamed: 3  \
# 3133      C2308         35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3134      C2308         35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3135      C2308         35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3136      C2308         35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3137      C2308         35        000  State - ANDAMAN & NICOBAR ISLANDS
#
#      Unnamed: 4  \
# 3133      Urban
# 3134      Urban
# 3135      Urban
# 3136      Urban
# 3137      Urban
#
#      C-8  EDUCATIONAL LEVEL BY AGE AND SEX FOR POPULATION AGE 7 AND ABOVE - 2011  \
# 3133                                              65-69
# 3134                                              70-74
# 3135                                              75-79
# 3136                                                80+
# 3137                                     Age not stated
#
# ...
