# %%
import pandas as pd
file_path="census+data.xlsx"

# %%
excel_data=pd.ExcelFile("census+data.xlsx")
print(excel_data.sheet_names)
# Out:
# ['C-08']

# %%
# Load the data from the sheet 'C-08'
df = pd.read_excel(excel_data, sheet_name='C-08')

# Preview the first few rows to understand the structure
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0      Table      State     Distt.  Area Name     Total/
# 1       Name       Code       Code        NaN     Rural/
# 2        NaN        NaN        NaN        NaN     Urban/
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN
#
#   C-8  EDUCATIONAL LEVEL BY AGE AND SEX FOR POPULATION AGE 7 AND ABOVE - 2011  \
# 0                                          Age-group
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                  1
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ... Unnamed: 35  \
# 0      Total        NaN        NaN  Illiterate  ...         NaN
# 1        NaN        NaN        NaN         NaN  ...         NaN
# 2        NaN        NaN        NaN         NaN  ...         NaN
# ...

# %%
# Load the data with the correct header row
df_corrected = pd.read_excel(file_path, sheet_name='C-08', header=3)

# Check the first few rows again to confirm the structure
df_corrected.head()
# Out:
#   Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3 Urban/ Unnamed: 5  Unnamed: 6  \
# 0        NaN         NaN         NaN        NaN    NaN        NaN     Persons
# 1        NaN         NaN         NaN        NaN    NaN          1           2
# 2        NaN         NaN         NaN        NaN    NaN        NaN         NaN
# 3      C2308         0.0         0.0      INDIA  Total   All ages  1210854977
# 4      C2308         0.0         0.0      INDIA  Total        0-6   164515253
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 35 not equal to degree   \
# 0      Males    Females    Persons  ...     Females              Persons
# 1          3          4          5  ...          31                   32
# 2        NaN        NaN        NaN  ...         NaN                  NaN
# 3  623270258  587584719  447216165  ...      345724              7238719
# 4   85752254   78762999  164515253  ...           0                    0
#
# ...

# %%
# Filter to get only the row for 'INDIA', 'Total', and 'All ages'
india_total_row = df_corrected[
    (df_corrected['Unnamed: 3'] == 'INDIA') &  # 'Area Name' column
    (df_corrected['Urban/'] == 'Total') &       # 'Urban/Rural' column
    (df_corrected['Unnamed: 5'] == 'All ages')  # 'Age-group' column
]
india_total_row
# Out:
#   Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3 Urban/ Unnamed: 5  Unnamed: 6  \
# 3      C2308         0.0         0.0      INDIA  Total   All ages  1210854977
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 35 not equal to degree   \
# 3  623270258  587584719  447216165  ...      345724              7238719
#
#   Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42  \
# 3     5354161     1884558    68288971    42120460    26168511     3031570
#
#   Unnamed: 43 Unnamed: 44
# 3     1647116     1384454
#
# [1 rows x 45 columns]

# %%
india_total_row['Unnamed: 6']
# Out:
# 3    1210854977
# Name: Unnamed: 6, dtype: object

# %%
# Extract the total number of persons for the 'INDIA' row
total_persons = pd.to_numeric(india_total_row['Unnamed: 6'], errors='coerce').iloc[0]

print(f"Total number of people included in the census dataset: {total_persons}")
# Out:
# Total number of people included in the census dataset: 1210854977

# %%
import pandas as pd
marks = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/VodvGKvJAaeNrG7kvOQV38aog/class-grades.csv')
marks
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17    30.00     63.15  48.89
# 3        7       81.22     96.06    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8       96.73    103.71    45.00     93.52  61.94
# 95       7       85.34     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
marks_cleaned = marks[marks.isna().sum(axis=1) != 5]

# %%
marks_cleaned
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17    30.00     63.15  48.89
# 3        7       81.22     96.06    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8       96.73    103.71    45.00     93.52  61.94
# 95       7       85.34     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [97 rows x 6 columns]

# %%
issing_values_per_column = marks_cleaned.isna().sum()

# %%
issing_values_per_column = marks_cleaned.isna().sum()

# %%
issing_values_per_column
# Out:
# Prefix         0
# Assignment     0
# Tutorial      10
# Midterm       14
# TakeHome       7
# Final          3
# dtype: int64
